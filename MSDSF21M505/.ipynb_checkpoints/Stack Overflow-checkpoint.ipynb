# %% [markdown]
# #### Section 1

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
df1=pd.read_csv("Datasets/survey_results_public.csv")
df1
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df1.shape
# Out:
# (83439, 48)

# %%
df2=pd.read_csv("Datasets/Survey_Result_Without_Header.csv", header=None)
df2
# Out:
#           0                                       1   \
# 0          1             I code primarily as a hobby
# 1          2          I am a developer by profession
# 2          3             I code primarily as a hobby
# 3          4          I am a developer by profession
# 4          5  I am a student who is learning to code
# ...      ...                                     ...
# 11436  11437          I am a developer by profession
# 11437  11438          I am a developer by profession
# 11438  11439          I am a developer by profession
# 11439  11440          I am a developer by profession
# 11440  11441          I am a developer by profession
#
#                                                       2   \
# 0                     Not employed, but looking for work
# 1                                                Retired
# 2                                     Student, full-time
# 3                                     Employed full-time
# ...

# %%
df2.shape
# Out:
# (11441, 48)

# %%
Columns=['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
       'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
       'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
       'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
       'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
       'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
       'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
       'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
       'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
       'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
       'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
       'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
       'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
       'SurveyEase', 'ConvertedCompYearly']

# %%
df2.columns=Columns
df2
# Out:
#        ResponseId                              MainBranch  \
# 0               1             I code primarily as a hobby
# 1               2          I am a developer by profession
# 2               3             I code primarily as a hobby
# 3               4          I am a developer by profession
# 4               5  I am a student who is learning to code
# ...           ...                                     ...
# 11436       11437          I am a developer by profession
# 11437       11438          I am a developer by profession
# 11438       11439          I am a developer by profession
# 11439       11440          I am a developer by profession
# 11440       11441          I am a developer by profession
#
#                                               Employment  \
# 0                     Not employed, but looking for work
# 1                                                Retired
# 2                                     Student, full-time
# ...

# %%
#https://gist.githubusercontent.com/MSDSF21M505/dcb43578cb1f035cc0faf399c0890577/raw/eb7e6125a9fce462bfe4670f1f4c2afcf83cd12b/Stackoverflow_data.csv
df3=pd.read_csv("https://bit.ly/3vjELzy")
df3.rename(columns={'1':"ResponseId"},inplace=True)
df3
# Out:
#        ResponseId                              MainBranch  \
# 0               2          I am a developer by profession
# 1               3          I am a developer by profession
# 2               4  I am a student who is learning to code
# 3               5          I am a developer by profession
# 4               6          I am a developer by profession
# ...           ...                                     ...
# 21994       21996  I am a student who is learning to code
# 21995       21997          I am a developer by profession
# 21996       21998          I am a developer by profession
# 21997       21999          I am a developer by profession
# 21998       22000          I am a developer by profession
#
#                                               Employment  \
# 0                                     Employed full-time
# 1                                     Employed full-time
# 2                     Not employed, but looking for work
# ...

# %%
df3.shape
# Out:
# (21999, 48)

# %%
df=pd.concat([df1,df2,df3],ignore_index=True)
df
# Out:
#         ResponseId                                         MainBranch  \
# 0                1                     I am a developer by profession
# 1                2             I am a student who is learning to code
# 2                3  I am not primarily a developer, but I write co...
# 3                4                     I am a developer by profession
# 4                5                     I am a developer by profession
# ...            ...                                                ...
# 116874       21996             I am a student who is learning to code
# 116875       21997                     I am a developer by profession
# 116876       21998                     I am a developer by profession
# 116877       21999                     I am a developer by profession
# 116878       22000                     I am a developer by profession
#
#                                                Employment  \
# 0       Independent contractor, freelancer, or self-em...
# ...

# %%
df.shape
# Out:
# (116879, 48)

# %%
df=df.drop(labels=['NEWSOSites','SOVisitFreq','SOAccount','SOPartFreq','SOComm','NEWOtherComms','Trans',"Sexuality","Ethnicity","Accessibility","MentalHealth","SurveyLength","SurveyEase","ConvertedCompYearly"], axis=1)
df
# Out:
#         ResponseId                                         MainBranch  \
# 0                1                     I am a developer by profession
# 1                2             I am a student who is learning to code
# 2                3  I am not primarily a developer, but I write co...
# 3                4                     I am a developer by profession
# 4                5                     I am a developer by profession
# ...            ...                                                ...
# 116874       21996             I am a student who is learning to code
# 116875       21997                     I am a developer by profession
# 116876       21998                     I am a developer by profession
# 116877       21999                     I am a developer by profession
# 116878       22000                     I am a developer by profession
#
#                                                Employment  \
# 0       Independent contractor, freelancer, or self-em...
# ...

# %%
df1.shape
# Out:
# (83439, 48)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 3973886

# %%
df.empty
# Out:
# False

# %%
df.index
# Out:
# RangeIndex(start=0, stop=116879, step=1)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'Age', 'Gender'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=116879, step=1),
#  Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#         'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#         'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#         'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#         'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#         'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#         'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#         'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#         'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#         'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#         'NEWStuck', 'Age', 'Gender'],
#        dtype='object')]

# %%
df.dtypes
# Out:
# ResponseId                        int64
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                       object
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# ...

# %%
df.count()
# Out:
# ResponseId                      116879
# MainBranch                      116879
# Employment                      116704
# Country                         116879
# US_State                         21684
# UK_Country                        6283
# EdLevel                         116454
# Age1stCode                      116586
# LearnCode                       116285
# YearsCode                       114803
# YearsCodePro                     85271
# DevType                          92621
# OrgSize                          84356
# Currency                         84854
# CompTotal                        65757
# CompFreq                         72441
# LanguageHaveWorkedWith          115288
# LanguageWantToWorkWith          107387
# DatabaseHaveWorkedWith           96992
# DatabaseWantToWorkWith           81192
# PlatformHaveWorkedWith           72779
# PlatformWantToWorkWith           58104
# WebframeHaveWorkedWith           85988
# WebframeWantToWorkWith           72574
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116879 entries, 0 to 116878
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ResponseId                    116879 non-null  int64
#  1   MainBranch                    116879 non-null  object
#  2   Employment                    116704 non-null  object
#  3   Country                       116879 non-null  object
#  4   US_State                      21684 non-null   object
#  5   UK_Country                    6283 non-null    object
#  6   EdLevel                       116454 non-null  object
#  7   Age1stCode                    116586 non-null  object
#  8   LearnCode                     116285 non-null  object
#  9   YearsCode                     114803 non-null  object
#  10  YearsCodePro                  85271 non-null   object
#  11  DevType                       92621 non-null   object
# ...

# %% [markdown]
# #### Section 2 (Data Cleaning)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116879 entries, 0 to 116878
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ResponseId                    116879 non-null  int64
#  1   MainBranch                    116879 non-null  object
#  2   Employment                    116704 non-null  object
#  3   Country                       116879 non-null  object
#  4   US_State                      21684 non-null   object
#  5   UK_Country                    6283 non-null    object
#  6   EdLevel                       116454 non-null  object
#  7   Age1stCode                    116586 non-null  object
#  8   LearnCode                     116285 non-null  object
#  9   YearsCode                     114803 non-null  object
#  10  YearsCodePro                  85271 non-null   object
#  11  DevType                       92621 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# ResponseId                           0
# MainBranch                           0
# Employment                         175
# Country                              0
# US_State                         95195
# UK_Country                      110596
# EdLevel                            425
# Age1stCode                         293
# LearnCode                          594
# YearsCode                         2076
# YearsCodePro                     31608
# DevType                          24258
# OrgSize                          32523
# Currency                         32025
# CompTotal                        51122
# CompFreq                         44438
# LanguageHaveWorkedWith            1591
# LanguageWantToWorkWith            9492
# DatabaseHaveWorkedWith           19887
# DatabaseWantToWorkWith           35687
# PlatformHaveWorkedWith           44100
# PlatformWantToWorkWith           58775
# WebframeHaveWorkedWith           30891
# WebframeWantToWorkWith           44305
# ...

# %%
clean_df=df

# %%
clean_df
# Out:
#         ResponseId                                         MainBranch  \
# 0                1                     I am a developer by profession
# 1                2             I am a student who is learning to code
# 2                3  I am not primarily a developer, but I write co...
# 3                4                     I am a developer by profession
# 4                5                     I am a developer by profession
# ...            ...                                                ...
# 116874       21996             I am a student who is learning to code
# 116875       21997                     I am a developer by profession
# 116876       21998                     I am a developer by profession
# 116877       21999                     I am a developer by profession
# 116878       22000                     I am a developer by profession
#
#                                                Employment  \
# 0       Independent contractor, freelancer, or self-em...
# ...

# %%
# employment=clean_df['Employment'].mode()
# uk_country=clean_df['UK_Country'].mode()
# edLevel=clean_df['EdLevel'].mode()
# age1stCode=clean_df['Age1stCode'].mode()
# learnCode=clean_df['LearnCode'].mode()
# yearsCode=clean_df['YearsCode'].mode()
# yearsCodePro=clean_df['YearsCodePro'].mode()
# devType=clean_df['DevType'].mode()
# orgSize=clean_df['OrgSize'].mode()
# currency=clean_df['Currency'].mode()
# compTotal=clean_df['CompTotal'].mode()
# compFreq=clean_df['CompFreq'].mode()
# languageHaveWorkedWith=clean_df['LanguageHaveWorkedWith'].mode()
# languageWantToWorkWith=clean_df['LanguageWantToWorkWith'].mode()
# databaseHaveWorkedWith=clean_df['DatabaseHaveWorkedWith'].mode()
# databaseWantToWorkWith=clean_df['DatabaseWantToWorkWith'].mode()
# platformHaveWorkedWith=clean_df['PlatformHaveWorkedWith'].mode()
# platformWantToWorkWith=clean_df['PlatformWantToWorkWith'].mode()
# webframeHaveWorkedWith=clean_df['WebframeHaveWorkedWith'].mode()
# webframeWantToWorkWith=clean_df['WebframeWantToWorkWith'].mode()
# miscTechHaveWorkedWith=clean_df['MiscTechHaveWorkedWith'].mode()
# miscTechWantToWorkWith=clean_df['MiscTechWantToWorkWith'].mode()
# toolsTechHaveWorkedWith=clean_df['ToolsTechHaveWorkedWith'].mode()
# toolsTechWantToWorkWith=clean_df['ToolsTechWantToWorkWith'].mode()
# nEWCollabToolsHaveWorkedWith=clean_df['NEWCollabToolsHaveWorkedWith'].mode()
# nEWCollabToolsWantToWorkWith=clean_df['NEWCollabToolsWantToWorkWith'].mode()
# opSys=clean_df['OpSys'].mode()
# nEWStuck=clean_df['NEWStuck'].mode()
# age=clean_df['Age'].mode()
# gender=clean_df['Gender'].mode()

# values={'Employment':employment,'UK_Country':uk_country,"EdLevel":edLevel,"Age1stCode":age1stCode,
#         "LearnCode":learnCode,"YearsCode":yearsCode,"YearsCodePro":yearsCodePro,"DevType":devType,
#        "OrgSize":orgSize,"Currency":currency,"CompTotal":compTotal,"CompFreq":compFreq,"LanguageHaveWorkedWith":languageHaveWorkedWith,
#         "LanguageWantToWorkWith":languageWantToWorkWith,"PlatformWantToWorkWith":platformWantToWorkWith,"DatabaseHaveWorkedWith":databaseHaveWorkedWith,"DatabaseWantToWorkWith":databaseWantToWorkWith,
#         "PlatformHaveWorkedWith":platformHaveWorkedWith,"WebframeHaveWorkedWith":webframeHaveWorkedWith,"WebframeWantToWorkWith":webframeWantToWorkWith,
#         "MiscTechHaveWorkedWith":miscTechHaveWorkedWith,"MiscTechWantToWorkWith":miscTechWantToWorkWith,"ToolsTechHaveWorkedWith":toolsTechHaveWorkedWith,
#         "ToolsTechWantToWorkWith":toolsTechWantToWorkWith,"NEWCollabToolsHaveWorkedWith":nEWCollabToolsHaveWorkedWith,"NEWCollabToolsWantToWorkWith":nEWCollabToolsWantToWorkWith,"OpSys":opSys,"NEWStuck":nEWStuck,
#         "Age":age,"Gender":gender
       
#        }

# %%
clean_df.fillna(method="ffill",inplace=True)

# %%
clean_df.isna().sum()
# Out:
# ResponseId                      0
# MainBranch                      0
# Employment                      0
# Country                         0
# US_State                        5
# UK_Country                      0
# EdLevel                         0
# Age1stCode                      0
# LearnCode                       0
# YearsCode                       0
# YearsCodePro                    0
# DevType                         0
# OrgSize                         0
# Currency                        0
# CompTotal                       0
# CompFreq                        0
# LanguageHaveWorkedWith          0
# LanguageWantToWorkWith          0
# DatabaseHaveWorkedWith          0
# DatabaseWantToWorkWith          0
# PlatformHaveWorkedWith          0
# PlatformWantToWorkWith          0
# WebframeHaveWorkedWith          0
# WebframeWantToWorkWith          0
# MiscTechHaveWorkedWith          0
# MiscTechWantToWorkWith          0
# ToolsTechHaveWorkedWith         0
# ...

# %%
us_state=clean_df['US_State'].mode()
us_state
# Out:
# 0    California
# dtype: object

# %%
clean_df["US_State"].fillna(value="California",inplace=True)

# %%
clean_df.isna().sum()
# Out:
# ResponseId                      0
# MainBranch                      0
# Employment                      0
# Country                         0
# US_State                        0
# UK_Country                      0
# EdLevel                         0
# Age1stCode                      0
# LearnCode                       0
# YearsCode                       0
# YearsCodePro                    0
# DevType                         0
# OrgSize                         0
# Currency                        0
# CompTotal                       0
# CompFreq                        0
# LanguageHaveWorkedWith          0
# LanguageWantToWorkWith          0
# DatabaseHaveWorkedWith          0
# DatabaseWantToWorkWith          0
# PlatformHaveWorkedWith          0
# PlatformWantToWorkWith          0
# WebframeHaveWorkedWith          0
# WebframeWantToWorkWith          0
# MiscTechHaveWorkedWith          0
# MiscTechWantToWorkWith          0
# ToolsTechHaveWorkedWith         0
# ...

# %%
clean_df
# Out:
#         ResponseId                                         MainBranch  \
# 0                1                     I am a developer by profession
# 1                2             I am a student who is learning to code
# 2                3  I am not primarily a developer, but I write co...
# 3                4                     I am a developer by profession
# 4                5                     I am a developer by profession
# ...            ...                                                ...
# 116874       21996             I am a student who is learning to code
# 116875       21997                     I am a developer by profession
# 116876       21998                     I am a developer by profession
# 116877       21999                     I am a developer by profession
# 116878       22000                     I am a developer by profession
#
#                                                Employment  \
# 0       Independent contractor, freelancer, or self-em...
# ...

# %% [markdown]
# #### Section 3 (Expolatory Data Analysis & Visualization)

# %%
df=clean_df

# %%
Languages=df.LanguageHaveWorkedWith.str.split(';')
print(Languages.count())
# Out:
# 116879

# %%
Language_Count=df.LanguageHaveWorkedWith.apply().value_counts()
Language_Count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\MUHAMM~1\AppData\Local\Temp/ipykernel_1804/2514925536.py in <module>
# ----> 1 Language_Count=df.LanguageHaveWorkedWith.apply(str.contains('PHP')).value_counts()
#       2 Language_Count
#
# AttributeError: type object 'str' has no attribute 'contains'
